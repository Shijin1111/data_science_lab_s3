# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fruits = ['mango','apple','banana','orange']
values = [3,8,2,4]
plt.bar(fruits,values,color="green")
plt.xlabel("fruits")
plt.ylabel("values")
# Out:
# Text(0, 0.5, 'values')
